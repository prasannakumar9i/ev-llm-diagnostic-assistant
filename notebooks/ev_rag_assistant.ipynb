# %% [markdown]
# <a href="https://colab.research.google.com/github/prasannakumar9i/ev-llm-diagnostic-assistant/blob/main/notebooks/ev_rag_assistant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EV LLM Diagnostic Assistant (RAG Project)
#
# Author: Sunny
# Project: EV AI Diagnostic Assistant
# Tools: Python, LangChain, FAISS, HuggingFace

# %% [markdown]
# ## Day 1 – Project Setup
#
# Goal:
# - Create GitHub repository
# - Connect Google Colab
# - Initialize project notebook

# %% [markdown]
# #Day 2 Install libraries

# %%
# !pip install langchain
# !pip  install sentence-transformers
# !pip install faiss-cpu
# !pip install pypdf
# !pip install transformers

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
import faiss

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')

print("Embedding model loaded successfully")

# %%
sentence = "EV battery draining quickly"

embedding = model.encode(sentence)

print(len(embedding))

# %% [markdown]
# # Day 3 — Download EV Repair Manuals Dataset

# %% [markdown]
# In this step, we collect EV repair manuals in PDF format.
# These manuals will act as the knowledge base for the AI diagnostic assistant.
# Later we will extract text from these PDFs and convert them into embeddings.

# %%
import os
os.makedirs("ev_manuals", exist_ok=True)
print("Folder created successfully")
# Out:
# Folder created successfully

# %%
# !wget -P ev_manuals https://www.tesla.com/sites/default/files/model_s_owners_manual_north_america_en.pdf
# Out:
# --2026-03-07 12:52:30--  https://www.tesla.com/sites/default/files/model_s_owners_manual_north_america_en.pdf
# Resolving www.tesla.com (www.tesla.com)... 23.0.204.90, 2600:1409:9800:159e::700, 2600:1409:9800:1587::700
# Connecting to www.tesla.com (www.tesla.com)|23.0.204.90|:443... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2026-03-07 12:52:30 ERROR 403: Forbidden.

# %%
import os
files = os.listdir("ev_manuals")
print("Downloaded Manuals", files)
# Out:
# Downloaded Manuals []
